# %%
import matplotlib
import numpy as np
from matplotlib.pyplot import *
from IPython import display
import seaborn as sns
sns.set()
sns.set_palette(sns.color_palette("Set2")) #coolwarm

# %% [markdown]
# # performence comparison during test

# %%
import matplotlib
import numpy as np
from matplotlib.pyplot import *
from IPython import display

sns.set_palette(sns.color_palette("Set2")) #coolwarm

dir_0 = "/Volumes/LYON/Coverage/test/seed"

num_points = 2000
r_1 = np.load(dir_0+ str(1) + "/train/Global_return.npy")[:num_points]
r_2 = np.load(dir_0+ str(2) + "/train/Global_return.npy")[:num_points]
r_3 = np.load(dir_0+ str(2) + "_/train/Global_return.npy")[:num_points]
r_4 = np.load(dir_0+ str(4) + "/train/Global_return.npy")[:num_points]
r_5 = np.load(dir_0+ str(5) + "/train/Global_return.npy")[:num_points]
r_6 = np.load(dir_0+ str(6) + "/train/Global_return.npy")[:num_points]
r_7 = np.load(dir_0+ str(7) + "/train/Global_return.npy")[:num_points]
r_8 = np.load(dir_0+ str(8) + "/train/Global_return.npy")[:num_points]
r_9 = np.load(dir_0+ str(9) + "/train/Global_return.npy")[:num_points]
r_10 = np.load(dir_0+ str(10) + "/train/Global_return.npy")[:num_points]
r_12 = np.load(dir_0+ str(12) + "/train/Global_return.npy")[:num_points]
r_13 = np.load(dir_0+ str(13) + "/train/Global_return.npy")[:num_points]
r_14 = np.load(dir_0+ str(14) + "/train/Global_return.npy")[:num_points]
r_15 = np.load(dir_0+ str(15) + "/train/Global_return.npy")[:num_points]
r_21 = np.load(dir_0+ str(21) + "/train/Global_return.npy")[:num_points]
r_22 = np.load(dir_0+ str(22) + "/train/Global_return.npy")[:num_points]
r_25 = np.load(dir_0+ str(25) + "/train/Global_return.npy")[:num_points]



plot(np.arange(len(r_1)), r_1, label='a3c seed 1') 
plot(np.arange(len(r_2)), r_2, label='a3c seed 2')
plot(np.arange(len(r_3)), r_3, label='a3c seed 3')#un-officially seed2_
# plot(np.arange(len(r_4)), r_4, label='a3c seed 4') #starts high
plot(np.arange(len(r_5)), r_5, label='a3c seed 5') #failed
plot(np.arange(len(r_6)), r_6, label='a3c seed 6') #starts high
plot(np.arange(len(r_7)), r_7, label='a3c seed 7') # TOO MUCH FLUC WITH 2
# plot(np.arange(len(r_8)), r_8, label='a3c seed 8') #starts high didnot finish
# plot(np.arange(len(r_9)), r_9, label='a3c seed 9') # FAILS 
plot(np.arange(len(r_10)), r_10, label='a3c seed 10') 
# plot(np.arange(len(r_12)), r_12, label='a3c seed 12') 
plot(np.arange(len(r_13)), r_13, label='a3c seed 13')
# plot(np.arange(len(r_14)), r_14, label='a3c seed 14') #starts high
# plot(np.arange(len(r_15)), r_15, label='a3c seed 15')
plot(np.arange(len(r_21)), r_21, label='a3c seed 21')
# plot(np.arange(len(r_22)), r_22, label='a3c seed 22')
plot(np.arange(len(r_25)), r_25, label='a3c seed 25')
print r_1[-1],r_2[-1],r_3[-1],r_4[-1],r_5[-1],r_6[-1],r_7[-1]
xlabel('Episode')
ylabel('Moving averaged episodic reward')
xlim(0,num_points)
# ylim (-200,-30)
legend(loc='lower right',fontsize=10)

# savefig("./plots/12sept/globalreturn_mlp_a3c_individual.pdf")
show()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-3-013869a9a6b4> in <module>()
#       9
#      10 num_points = 2000
# ---> 11 r_1 = np.load(dir_0+ str(1) + "/train/Global_return.npy")[:num_points]
#      12 r_2 = np.load(dir_0+ str(2) + "/train/Global_return.npy")[:num_points]
#      13 r_3 = np.load(dir_0+ str(2) + "_/train/Global_return.npy")[:num_points]
#
# /home/sam/Documents/DRL_UAV_CellularNet/venv/local/lib/python2.7/site-packages/numpy/lib/npyio.pyc in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     413         own_fid = False
#     414     else:
# --> 415         fid = open(os_fspath(file), "rb")
#     416         own_fid = True
#     417
#
# IOError: [Errno 2] No such file or directory: '/Volumes/LYON/Coverage/test/seed1/train/Global_return.npy'

# %%
#

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
sns.set_palette(sns.color_palette("pastel")) #coolwarm
# palette = plt.get_cmap('coolwarm')
sns.set_style("darkgrid")
opacity = 0.7

# r_all_a3c = np.asarray([r_1, r_2, r_6, r_7, r_12,r_13, r_21, r_22]) #2k
r_all_a3c = np.asarray([r_1, r_2, r_3, r_5, r_6, r_7, r_9, r_10, r_13, r_21]) #1k
# r_all_a3c = np.asarray([r_1, r_2, r_3, r_5, r_6, r_7, r_9, r_10, r_12, r_13, r_15, r_21, r_22,r_25]) 
r_max_a3c = np.max(r_all_a3c, axis=0)
r_min_a3c = np.min(r_all_a3c, axis=0)
r_mean_a3c = np.mean(r_all_a3c, axis=0)
fill_between(np.arange(num_points), r_min_a3c, r_max_a3c, where=r_max_a3c >= r_min_a3c, 
             alpha=opacity, edgecolor='none', interpolate=True)
plot(np.arange(num_points), r_mean_a3c, label='DRL', color='royalblue')

# plot(np.arange(len(r_1)), r_22, label='') #starts high
xlabel('Episode', fontsize = 14)
ylabel('Moving Average of Episodic Return', fontsize = 14)
xticks(fontsize = 14)
yticks(fontsize = 14)
ylim(-300,300)
xlim(0,1000)
legend(loc=4, fontsize = 14)

# savefig("./convergence_1k_.pdf", bbox_inches='tight')
show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-820103b6dc42> in <module>()
#       9
#      10 # r_all_a3c = np.asarray([r_1, r_2, r_6, r_7, r_12,r_13, r_21, r_22]) #2k
# ---> 11 r_all_a3c = np.asarray([r_1, r_2, r_3, r_5, r_6, r_7, r_9, r_10, r_13, r_21]) #1k
#      12 # r_all_a3c = np.asarray([r_1, r_2, r_3, r_5, r_6, r_7, r_9, r_10, r_12, r_13, r_15, r_21, r_22,r_25])
#      13 r_max_a3c = np.max(r_all_a3c, axis=0)
#
# NameError: name 'r_1' is not defined

# %%
sns.set_palette(sns.color_palette("Set2")) 

greedy_dir = "/Volumes/LYON/Coverage/test/gradient/test_greedy_sinr_1step/"
greedy_reward = np.load(greedy_dir+"reward1.npy")
greedy_reward = greedy_reward.T
greedy_nHO = greedy_reward[0][-10000:]*20
greedy_nOut = greedy_reward[1][-10000:]*-40

gradient_dir = "/Volumes/LYON/Coverage/test/gradient/test_v1/"
gradient_reward = np.load(gradient_dir+"reward1.npy")
gradient_reward = gradient_reward.T
gradient_nHO = gradient_reward[0][-10000:]*20
gradient_nOut = gradient_reward[1][-10000:]*-40


test_dir = dir_0 + "2_/test/" #ac
test_reward = np.load(test_dir+"1000reward.npy")
test_reward = test_reward.T
nHO = test_reward[0][-10000:]*20
nOut = test_reward[1][-10000:]*-40

fig = figure(6, (6, 4.1))
subplot(1,2,1)
n_bins = 1000

hist(nHO, n_bins, normed=1, histtype='step',
                           cumulative=True)
hist(gradient_nHO, n_bins, normed=1, histtype='step',
                           cumulative=True)
hist(greedy_nHO, n_bins, normed=1, histtype='step',
                           cumulative=True)
# hist(greedy_nHO, n_bins, normed=1, histtype='step',
#                            cumulative=True)

# legend(loc=4)
xticks(np.arange(-5,16,5), fontsize = 14)
xlim(-5,30)
yticks(fontsize = 14)
xlabel("Mean UE SINR [dB]",fontsize = 14)
ylabel("CDF as per Step",fontsize = 14)
title("Mean SINR",fontsize = 14)
subplot(1,2,2)


hist(nOut, n_bins, normed=1, histtype='step',
                           cumulative=True, label='DRL')

hist(gradient_nOut, n_bins, normed=1, histtype='step',
                           cumulative=True, label='Gradient')

hist(greedy_nOut, n_bins, normed=1, histtype='step',
                           cumulative=True, label='gradient v2')
# legend(loc=4)
xticks(np.arange(0,16,5), fontsize = 14)
yticks(fontsize = 14)
xlabel("Number of UEs",fontsize = 14)
title("Outage",fontsize = 14)
# instances = ['DPPO', 'A3C', 'Greedy']
fig.subplots_adjust(top=0.93, bottom=0.2, hspace=0.4)
lgd=fig.legend(fontsize = 14, ncol =5, loc = (0.3, -0.00), 
           facecolor='None', edgecolor='None')
# lgd=fig.legend(instances, fontsize = 12, ncol =3, loc = (0.2, -0.00), 
#            facecolor='None', edgecolor='None')

# %%
import matplotlib
import numpy as np
from matplotlib.pyplot import *
from IPython import display
import seaborn as sns
sns.set()
sns.set_palette(sns.color_palette("Set2")) #coolwarm

sns.set_palette(sns.color_palette("coolwarm")) 

sns.set_style("darkgrid")

test_dir = "/Volumes/LYON/Coverage/test/seed2_/test/"
sinr_gradient = np.ravel(np.load("/Volumes/LYON/Coverage/test/gradient/test_v1/sinr.npy"))
sinr_random = np.ravel(np.load("/Volumes/LYON/Coverage/test/random/test/sinr.npy"))
sinr_greedy_sinr = np.ravel(np.load("/Volumes/LYON/Coverage/test/gradient/test_greedy_sinr_1step/sinr.npy"\
                                   ))


sinr_a3c_500 = np.ravel(np.load(test_dir+"500sinr.npy"))
sinr_a3c_1000 = np.ravel(np.load(test_dir+"1000sinr.npy"))
# sinr_a3c_1500 = np.ravel(np.load(test_dir+"1500sinr.npy"))
sinr_a3c_2000 = np.ravel(np.load(test_dir+"2000sinr.npy"))
sinr_a3c_init = np.ravel(np.load(test_dir+"_initsinr.npy"))
sinr_a3c = np.ravel(np.load(test_dir+"sinr.npy"))
# print np.shape(sinr_random), np.shape(sinr_a3c)
figure(figsize=(6,4))

n_bins = 1000
# sorted(sinr_a3c_2000)

X = sinr_a3c_2000
n = np.arange(1,len(X)+1) / np.float(len(X))
Xs = np.sort(X)
fig, ax = subplots()
ax.step(Xs,n,label="DRL 2,000 EPs") 

X = sinr_a3c_1000
n = np.arange(1,len(X)+1) / np.float(len(X))
Xs = np.sort(X)
# fig, ax = subplots()
ax.step(Xs,n,label="DRL 1,000 EPs") 

X = sinr_a3c_500
n = np.arange(1,len(X)+1) / np.float(len(X))
Xs = np.sort(X)
# fig, ax = subplots()
ax.step(Xs,n,label="DRL 500 EPs") 

X = sinr_a3c_init
n = np.arange(1,len(X)+1) / np.float(len(X))
Xs = np.sort(X)
# fig, ax = subplots()
ax.step(Xs,n,label="DRL 100 EPs") 

X = sinr_gradient
n = np.arange(1,len(X)+1) / np.float(len(X))
Xs = np.sort(X)
# fig, ax = subplots()
ax.step(Xs,n,label="Benchmark") 

X = sinr_greedy_sinr
n = np.arange(1,len(X)+1) / np.float(len(X))
Xs = np.sort(X)
# fig, ax = subplots()
ax.step(Xs,n,label="Search (Optimal)") 


legend(loc=4,fontsize = 14,framealpha=1)

# print np.shape(sinr_gradient), np.shape(sinr_random), \
# np.shape(sinr_a3c_2000), np.shape(sinr_greedy_sinr)
legend(loc=4,fontsize = 14,framealpha=1)
# xticks(np.arange(0,16,2), fontsize = 12)
xlim(-10,45)
yticks(fontsize = 16)
xticks(fontsize = 16)

ylabel("CDF",fontsize = 16)
xlabel("SINR [dB]",fontsize = 16)
show()

# %%
import matplotlib
import numpy as np
from matplotlib.pyplot import *
from IPython import display
# import seaborn as sns
# sns.set()
# sns.set_palette(sns.color_palette("coolwarm")) #coolwarm
i = 3
fig_size = (2.5,2.5)
while i <= 3:
    ue_loc = np.load("../../coverage/sinr_plot_data/sinr/ue_loc" + str(i) + ".npy")
    sinr_all = np.load("../../coverage/sinr_plot_data/sinr/sinr_map" + str(i) + ".npy")
    sinr_ue = np.load("../../coverage/sinr_plot_data/sinr/assoc_sinr" + str(i) + ".npy")

    ue_loc[:10] = ue_loc[:10] + [0, 45]
    ue_loc[-20:-10] = ue_loc[-20:-10] + [0, 40]
    ue_loc[-10:] = ue_loc[-10:] + [0, 10]

#     subplot(1,2,1)
    figure(figsize = fig_size)
    imshow(sinr_all, interpolation='nearest', origin='lower', vmin= -50, vmax = 100)

    plot(ue_loc[:,0], ue_loc[:,1], '+', color='silver', markersize=3)

#     'cyan'
    colorbar()
    grid(False)
    xticks(np.arange(0,100,20), np.arange(0,100,20)*5, fontsize=10)
    yticks(np.arange(0,101,20), np.arange(0,101,20)*5, fontsize=10)
    xlabel('X [m]', fontsize=10)
    ylabel('Y [m]', fontsize=10)

    savefig("./sinr_map_.pdf",  bbox_inches='tight')

    figure(figsize = fig_size)
    hist(sinr_ue, bins=40, fc='black', ec='none')
    
    grid(False)
    xlabel("Service SINR [dB]", fontsize=12)
    ylabel("Number of UEs", fontsize=12)
    xticks(np.arange(-5,21,5), fontsize=12)
    yticks(fontsize=12)

    ylim(0,6)
#     subplots_adjust(wspace=0.3)

#     savefig("./",  bbox_inches='tight')
    i += 1

# %%
import numpy as np 
import matplotlib
from matplotlib.pyplot import *

reward = np.load("./test/A3C_median_SINR/reward.npy")
sinr = np.load("./test/A3C_median_SINR/sinr.npy")
time = np.load("./test/A3C_median_SINR/time.npy")
print(time)
time_sum = 0
for index in range(len(time)):
    time_sum += time[index]
    time[index] = time_sum


plot(time, reward)
# Out:
# [0.01547599 0.00400496 0.00418019 ... 0.00509501 0.004143   0.00452685]

# %%
import numpy as np
import matplotlib
from matplotlib.pyplot import *

global_train_reward = np.load('./train/A3C_median_SINR/Global_return.npy')
print(global_train_reward)

plot(np.arange(202), global_train_reward)
# Out:
# [338.99120772 335.20039034 333.9040273  326.50642444 325.9917222
#  320.48230105 315.42935564 313.57891606 309.93543499 308.23195584
#  308.52085087 305.01461379 298.26956914 294.28753084 293.65744554
#  292.65945166 290.77076148 284.7203838  281.38475312 280.40254062
#  275.95418014 272.27914531 268.63471476 271.78267769 268.16527302
#  266.55700542 263.58285438 261.02032888 259.14996887 258.52987038
#  261.41830553 260.75121141 258.59660769 254.97954732 255.63096821
#  252.53665037 252.31913118 252.31294963 250.93814942 251.61519232
#  251.24981189 251.35153434 247.16576106 247.60508472 244.69444637
#  243.93496455 245.53403251 242.5255215  240.96452228 245.14019636
#  247.47177127 248.01691807 247.23402369 243.53033815 241.29529733
#  239.18593568 242.72185558 244.70579059 243.48973735 239.90171491
#  242.80005901 243.0602525  244.65334832 240.12671084 240.17921977
#  237.03783167 233.05620399 232.61886557 233.00237993 231.41947075
# ...

# %% [markdown]
# Testing outages across test run

# %%
import numpy as np
import matplotlib
from matplotlib.pyplot import *

outages = np.load('./test/A3C_median_SINR/outage_fraction.npy')
outages_buckets = []
for index in range(0, outages.shape[0] - 100, 100):
    outages_buckets.append(np.mean(outages[index:index+100]))
print(len(outages_buckets))
plot(np.arange(20, outages_buckets))
# Out:
# 20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-f260c5feacc1> in <module>
#       8     outages_buckets.append(np.mean(outages[index:index+100]))
#       9 print(len(outages_buckets))
# ---> 10 plot(np.arange(20, outages_buckets))
#
# TypeError: unsupported operand type(s) for -: 'list' and 'int'

# %% [markdown]
# Printing locations across test run

# %%
import numpy as np
import matplotlib
from matplotlib.pyplot import *

ue_location = np.load('./test/A3C_median_SINR/ue_location.npy')
bs_location = np.load('./test/A3C_median_SINR/bs_location.npy')
actions = np.load('./test/A3C_median_SINR/action.npy')
reward = np.load('./test/A3C_median_SINR/reward.npy')
print(reward)
print(reward.shape)

for index in range(0, 2000, 10):
#     print(actions[index])
#     print(bs_location[index])
    print(reward[index])
    ue_location_run = ue_location[index]
    bs_location_run = bs_location[index]
    scatter(*zip(*ue_location_run), marker='o', c='blue')
    scatter(*zip(*bs_location_run), marker='+', c='red')
    show()
    close()
# Out:
# [ 0.21097928  0.34094636  0.31842485 ... -0.30664325 -0.20137354
#  -0.22514   ]
# (2001,)
# 0.21097928488771045
# 0.5445073720525674
# 0.385388087583448
# 0.40125316699114294
# 0.3797876068471831
# 0.4170987061289209
# 0.20419649525093442
# 0.2185142680493602
# 0.249936179393019
# 0.4410223505154548
# 0.5415339950082334
# 0.46689071686714456
# 0.5131046309280631
# 0.4174674744076415
# 0.40496086575992546
# 0.5955922764800078
# 0.5582509854095513
# 0.5017928458033888
# 0.39089824268915135
# 0.5858760157647632
# 0.5750703098645521
# 0.579023856042047
# 0.9590518034012714
# 0.4901493719822933
# 0.34854932752718126
# 0.2936324412064679
# 0.35226203260408345
# 0.36336313372627554
# 0.4009290617642767
# 0.2796034775818297
# 0.4287628941551342
# 0.5653038990798787
# 0.5959757605897882
# 0.5952217252920127
# 0.4611803951176091
# 0.34528194368834775
# 0.2702370641659283
# 0.12169678065016881
# 0.3053645563369658
# 0.3476004337835996
# 0.3797322418720798
# 0.37528219726413486
# ...
